# %% [markdown]
# # 松材线虫病知识图谱构建 - Notebook版
#
# 本Notebook直接使用项目现有模块，与main.py功能完全一致。
#
# ## 使用说明
# 1. 确保Ollama运行中: `ollama serve`
# 2. 确保已下载模型: `ollama pull llama3.2:3b`
# 3. PDF文献放入 `文献/` 目录
# 4. 按顺序执行单元格

# %% [markdown]
# ## 1. 导入项目模块

# %%
import os
import sys
from datetime import datetime

# 导入项目模块
from enhanced_pipeline import EnhancedKnowledgeGraphPipeline
from data_cleaner import DataCleaner
from neo4j_generator import Neo4jGenerator
from config_loader import load_config
from logger_config import get_logger
from main import generate_statistics_report

print("✓ 项目模块已导入")
# Out:
# ✓ 项目模块已导入

# %% [markdown]
# ## 2. 加载配置

# %%
# 加载config.yaml
config = load_config()
logger = get_logger('Notebook')

# 提取配置
PDF_DIR = config.get('pdf.input_directory', './文献')
OUTPUT_DIR = config.get('output.base_directory', './output')
CONFIDENCE_THRESHOLD = config.get('cleaning.confidence_threshold', 0.65)

print("配置信息:")
print(f"  PDF目录: {PDF_DIR}")
print(f"  输出目录: {OUTPUT_DIR}")
print(f"  LLM模型: {config.get('llm.model')}")
print(f"  处理块数: {config.get('llm.max_chunks', 'ALL')}")
print(f"  缓存: {config.get('system.enable_cache')}")
# Out:
# INFO - 配置文件已加载: ./config/config.yaml
# 配置信息:
#   PDF目录: ./文献
#   输出目录: ./output
#   LLM模型: llama3.2:3b
#   处理块数: 100
#   缓存: True

# %% [markdown]
# ## 3. 运行增强型管道
#
# 这一步会自动完成:
# - PDF提取(带缓存)
# - 文本分块
# - LLM概念提取
# - 邻近性分析
# - 概念去重
# - 过滤和保存

# %%
# 初始化管道
pipeline = EnhancedKnowledgeGraphPipeline(config)

# 运行管道
start_time = datetime.now()
print(f"开始时间: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")
print("="*60)

concepts_df, relationships_df = pipeline.run(PDF_DIR)

end_time = datetime.now()
print("="*60)
print(f"完成时间: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
print(f"总耗时: {end_time - start_time}")
print(f"\n提取概念: {len(concepts_df)}")
print(f"提取关系: {len(relationships_df)}")
# Out:
# INFO - Initializing concept extractor...
# INFO - ✓ Concept extractor initialized
# INFO - Initializing concept deduplicator...
# INFO - ✓ Concept deduplicator initialized
# INFO - ============================================================
# INFO - Starting Enhanced Knowledge Graph Pipeline
# INFO - ============================================================
# INFO -
# [Step 1/6] Extracting text from PDFs...
# INFO - 缓存目录: output/cache
# INFO - 并行处理器已初始化: 4 个工作进程
# INFO - PDF缓存已启用
# INFO - 并行处理已启用: 4 个工作进程
# INFO - 找到 14 个PDF文件
# INFO - 使用并行处理: 4 个进程
# INFO - 开始并行处理 14 个文件，使用 4 个进程
# 开始时间: 2025-11-15 18:15:55
# ============================================================
# 找到 14 个PDF文件
# 提取PDF文本:   0%|          | 0/14 [00:00<?, ?it/s]INFO - OCR功能可用 (pytesseract)
# INFO - OCR功能可用 (pytesseract)
# INFO - OCR功能可用 (pytesseract)
# INFO - OCR功能可用 (pytesseract)
# INFO - PaddleOCR可用（推荐用于中文）
# INFO - PaddleOCR可用（推荐用于中文）
# INFO - PaddleOCR可用（推荐用于中文）
# INFO - PaddleOCR可用（推荐用于中文）
# 提取PDF文本: 100%|██████████| 14/14 [00:18<00:00,  1.31s/it]
# INFO - 并行处理完成: 成功 14/14
# INFO -
# [Step 2/6] Splitting texts into chunks...
# INFO - Created 321 chunks
# INFO -
# [Step 3/6] Extracting concepts and relationships using LLM...
# INFO - Processing limit: 100 chunks
# ⚠️  Limiting processing to 100 chunks (out of 321)
#     Set max_chunks=None in code to process all chunks
# ✓ ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf: 提取了 97457 个字符
# ✓ 4ERGo-1762148839583-泰山松材线虫病、美国白蛾风险分析评估与预警技术研究_申卫星.pdf: 提取了 69638 个字符
# ✓ 基于灰色关联度分析气候因素对江西省松材线虫病的影响.pdf: 提取了 18707 个字符
# ✓ Pc5Bj-1762148820023-松材线虫病媒介天牛种类调查及其传播机制研究_王洋.pdf: 提取了 115778 个字符
# ✓ 气候变化对松材线虫病扩散风险的影响分析——以郁南县为例_雷志华.pdf: 提取了 5630 个字符
# ✓ 我国松材线虫病的扩散趋势及气候对疫情的影响研究_张潮.pdf: 提取了 43477 个字符
# ✓ 气候要素对松材线虫病疫情的影响研究.pdf: 提取了 12326 个字符
# ✓ JU3yc-1762148851602-马尾松蛀干害虫种群动态与松材线虫病的关系及松褐天牛天敌研究_展茂魁.pdf: 提取了 131166 个字符
# ✓ 松材线虫病疫情指数与气候因素之间的关系.pdf: 提取了 18167 个字符
# ✓ JItW6-1762148810582-中国森林保护学科发展历程研究_曾凡勇.pdf: 提取了 132512 个字符
# ✓ XlZVN-1762148845443-浙江省松材线虫病环境影响经济评价与治理研究_李兰英.pdf: 提取了 172287 个字符
# ✓ 气候要素对天台松材线虫病疫情的影响.pdf: 提取了 5603 个字符
# ✓ 气候变化背景下松材线虫在中国分布的时空变化预测.pdf: 提取了 18937 个字符
# ✓ 基于长汀水土流失治理过程中马尾松林松材线虫病与气候因素之间的关系.pdf: 提取了 5527 个字符
# Processing chunks:   0%|          | 0/100 [00:00<?, ?it/s]Ollama timeout (attempt 1/3), retrying...
# Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_0
# Processing chunks:   1%|          | 1/100 [03:01<4:58:58, 181.20s/it]Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_1
# Processing chunks:   2%|▏         | 2/100 [03:33<2:33:07, 93.75s/it] Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_2
# Processing chunks:   3%|▎         | 3/100 [04:00<1:42:00, 63.10s/it]Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_3
# Processing chunks:   4%|▍         | 4/100 [04:17<1:12:13, 45.14s/it]Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_4
# Processing chunks:   5%|▌         | 5/100 [04:54<1:06:31, 42.01s/it]Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_5
# Processing chunks:   6%|▌         | 6/100 [05:18<56:03, 35.79s/it]  Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_6
# Processing chunks:   7%|▋         | 7/100 [06:55<1:26:34, 55.85s/it]Ollama timeout (attempt 1/3), retrying...
# Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_7
# Processing chunks:   8%|▊         | 8/100 [10:10<2:33:31, 100.12s/it]Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_8
# Processing chunks:   9%|▉         | 9/100 [12:06<2:39:29, 105.16s/it]Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_9
# Processing chunks:  10%|█         | 10/100 [13:13<2:19:54, 93.27s/it]Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_10
# Processing chunks:  11%|█         | 11/100 [14:26<2:09:07, 87.05s/it]Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_11
# Processing chunks:  12%|█▏        | 12/100 [15:13<1:49:53, 74.93s/it]Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_12
# Processing chunks:  13%|█▎        | 13/100 [16:18<1:44:30, 72.07s/it]Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_13
# Processing chunks:  14%|█▍        | 14/100 [16:58<1:29:06, 62.17s/it]Ollama timeout (attempt 1/3), retrying...
# Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_14
# Processing chunks:  15%|█▌        | 15/100 [20:23<2:29:22, 105.45s/it]Failed to parse JSON for chunk ZGds6-1762148816090-松材线虫病害早期星-机-地遥感诊断光谱特征研究_李霓雯.pdf_15
# Processing chunks:  16%|█▌        | 16/100 [21:45<2:17:25, 98.17s/it] Ollama API error (attempt 1/3): ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b0d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299690>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  17%|█▋        | 17/100 [22:10<1:45:28, 76.25s/it]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2982e0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298640>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b0d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  18%|█▊        | 18/100 [22:10<1:12:56, 53.37s/it]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d279300>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2987c0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299690>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299870>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d279300>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b0d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  20%|██        | 20/100 [22:10<38:19, 28.75s/it]  Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299cc0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298b80>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29ae60>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b7c0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b7f0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27be50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  22%|██▏       | 22/100 [22:10<22:32, 17.34s/it]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a0e0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298460>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b160>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27ab90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b7c0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299360>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  24%|██▍       | 24/100 [22:10<14:02, 11.08s/it]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a050>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a440>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2796f0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bcd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29acb0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299510>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  26%|██▌       | 26/100 [22:10<09:02,  7.33s/it]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a650>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27abc0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b400>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b6d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2997e0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2987c0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  28%|██▊       | 28/100 [22:11<05:56,  4.95s/it]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a680>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2796f0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27ad40>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b3a0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299270>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a980>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  30%|███       | 30/100 [22:11<03:57,  3.40s/it]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27aa40>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b700>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b9a0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2999c0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299600>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299540>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  32%|███▏      | 32/100 [22:11<02:40,  2.36s/it]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bc70>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27a800>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299120>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a830>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29afb0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27a7a0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b700>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b1c0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29ac50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299390>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299ff0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2796f0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  36%|███▌      | 36/100 [22:11<01:20,  1.26s/it]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bb50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a650>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29ae90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299c00>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bdc0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b310>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298ac0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2982b0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29ab30>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  39%|███▉      | 39/100 [22:11<00:51,  1.18it/s]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27aef0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bd60>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bbb0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299300>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299030>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298f70>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d279810>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bc70>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299060>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  42%|████▏     | 42/100 [22:11<00:33,  1.71it/s]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298d30>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298940>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27ba60>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d279e70>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27ac20>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299540>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2997e0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29b010>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27af20>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  45%|████▌     | 45/100 [22:11<00:22,  2.42it/s]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b9a0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29af50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2996c0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2989a0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27ace0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d279db0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b700>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a920>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299600>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  48%|████▊     | 48/100 [22:11<00:15,  3.38it/s]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29af20>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b310>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bd30>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298160>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a590>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29b850>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bca0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bb50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27acb0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  51%|█████     | 51/100 [22:12<00:10,  4.64it/s]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299330>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2991e0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29afb0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27aaa0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b820>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29aa10>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298430>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29af80>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b790>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  54%|█████▍    | 54/100 [22:12<00:07,  5.99it/s]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27acb0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b670>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29b7c0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298640>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2990f0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2791e0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b130>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a8f0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298940>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  57%|█████▋    | 57/100 [22:12<00:05,  7.30it/s]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2982e0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298f70>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d279210>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27a920>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298190>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2996c0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a980>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bdf0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27ab00>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  60%|██████    | 60/100 [22:12<00:04,  9.47it/s]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27ab30>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a8f0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298190>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27aef0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27ae00>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bdf0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299120>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29abf0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2988b0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  63%|██████▎   | 63/100 [22:12<00:03, 11.68it/s]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27aec0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27a800>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b610>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298790>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2987c0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# ...
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bbb0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299c60>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a980>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29b610>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bb80>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  87%|████████▋ | 87/100 [22:13<00:00, 28.63it/s]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27ae00>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27ac20>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29ac20>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298ca0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a020>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27aef0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27af20>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27ac80>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29b520>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2997b0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d299f30>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27a9b0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  91%|█████████ | 91/100 [22:13<00:00, 18.50it/s]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27ad40>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29b1c0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29acb0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29a320>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b340>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27aec0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298d90>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298790>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2998d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27beb0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b1f0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b130>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d2987f0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298700>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bdc0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks:  96%|█████████▌| 96/100 [22:13<00:00, 22.53it/s]Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27af80>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27aa10>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298cd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29b0d0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27b9a0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bbb0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d279810>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298c40>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d29acb0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 1/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298340>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 2/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d298f10>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Ollama API error (attempt 3/3): HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x31d27bdf0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Processing chunks: 100%|██████████| 100/100 [22:14<00:00, 13.34s/it]
# INFO - Extracted 0 concepts and 0 LLM relationships
# INFO -
# [Step 4/6] Analyzing contextual proximity...
# INFO - Extracted 0 proximity relationships
# INFO -
# [Step 5/6] Merging and deduplicating concepts...
# INFO - Merged relationships: 0
# INFO -
# [Step 6/6] Filtering and finalizing...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 9
#       6 print(f"开始时间: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")
#       7 print("="*60)
# ----> 9 concepts_df, relationships_df = pipeline.run(PDF_DIR)
#      11 end_time = datetime.now()
#      12 print("="*60)
#
# File ~/Desktop/PWD/enhanced_pipeline.py:140, in EnhancedKnowledgeGraphPipeline.run(self, pdf_dir)
#     138 # Step 6: Filter and finalize
#     139 logger.info("\n[Step 6/6] Filtering and finalizing...")
# --> 140 concepts_df, relationships_df = self._filter_and_finalize(concepts_df, relationships_df)
#     142 # Save intermediate results
#     143 self._save_results(concepts_df, relationships_df)
#
# File ~/Desktop/PWD/enhanced_pipeline.py:256, in EnhancedKnowledgeGraphPipeline._filter_and_finalize(self, concepts_df, relationships_df)
#     249 """
#     250 Filter concepts by importance and connectivity
#     251
#     252 Returns:
#     253     Tuple of (filtered_concepts_df, filtered_relationships_df)
#     254 """
#     255 # Filter concepts
# --> 256 filtered_concepts = ConceptImportanceFilter.filter_concepts(
#     257     concepts_df, relationships_df,
#     258     min_importance=self.min_concept_importance,
#     259     min_connections=self.min_connections
#     260 )
#     262 # Filter relationships to only include remaining concepts
#     263 if not filtered_concepts.empty:
#
# File ~/Desktop/PWD/concept_deduplicator.py:347, in ConceptImportanceFilter.filter_concepts(concepts_df, relationships_df, min_importance, min_connections)
#     344 # Filter out generic concepts
#     345 initial_count = len(filtered_df)
#     346 filtered_df = filtered_df[
# --> 347     ~filtered_df['entity'].str.lower().isin(ConceptImportanceFilter.GENERIC_CONCEPTS)
#     348 ]
#     349 generic_filtered = initial_count - len(filtered_df)
#     350 if generic_filtered > 0:
#
# File ~/Desktop/PWD/venv/lib/python3.10/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/Desktop/PWD/venv/lib/python3.10/site-packages/pandas/core/indexes/range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# --> 418     raise KeyError(key)
#     419 self._check_indexing_error(key)
#     420 raise KeyError(key)
#
# KeyError: 'entity'

# %% [markdown]
# ## 4. 数据清洗

# %%
# 转换为实体格式
entities_clean = concepts_df.copy()
entities_clean.rename(columns={'entity': 'name'}, inplace=True)

if 'id' not in entities_clean.columns:
    entities_clean['id'] = entities_clean['name']
if 'type' not in entities_clean.columns:
    entities_clean['type'] = entities_clean.get('category', 'concept')

# 转换关系格式
relations_clean = relationships_df.copy()
relations_clean.rename(columns={
    'node_1': 'head',
    'node_2': 'tail',
    'edge': 'relation'
}, inplace=True)

if 'confidence' not in relations_clean.columns:
    relations_clean['confidence'] = relations_clean.get('weight', 0.5)
if 'source_pdf' not in relations_clean.columns and 'chunk_id' in relations_clean.columns:
    relations_clean['source_pdf'] = relations_clean['chunk_id'].str.split('_').str[0]

# 保存
entities_clean.to_csv(f"{OUTPUT_DIR}/entities_clean.csv", index=False, encoding='utf-8-sig')
relations_clean.to_csv(f"{OUTPUT_DIR}/relations_clean.csv", index=False, encoding='utf-8-sig')

print(f"✓ 清洗后实体: {len(entities_clean)}")
print(f"✓ 清洗后关系: {len(relations_clean)}")

# %% [markdown]
# ## 5. 生成Neo4j文件

# %%
# 使用Neo4jGenerator
generator = Neo4jGenerator(output_dir=f"{OUTPUT_DIR}/neo4j_import")
generator.generate_all(entities_clean, relations_clean)

print("\n✓ Neo4j导入文件已生成")

# %% [markdown]
# ## 6. 生成统计报告

# %%
# 生成统计报告
generate_statistics_report(entities_clean, relations_clean, OUTPUT_DIR)

print("\n✓ 统计报告已生成")

# %% [markdown]
# ## 7. 数据预览

# %%
# 显示概念
print("概念样例:")
display(concepts_df.head(10))

print("\n实体样例:")
display(entities_clean.head(10))

# %%
# 显示关系
print("关系样例:")
display(relations_clean.head(10))

# %% [markdown]
# ## 8. 完成总结

# %%
print("="*60)
print("✓ 知识图谱构建完成!")
print("="*60)
print(f"\n输出目录: {os.path.abspath(OUTPUT_DIR)}")
print("\n生成文件:")
print(f"  1. {OUTPUT_DIR}/concepts.csv")
print(f"  2. {OUTPUT_DIR}/relationships.csv")
print(f"  3. {OUTPUT_DIR}/entities_clean.csv")
print(f"  4. {OUTPUT_DIR}/relations_clean.csv")
print(f"  5. {OUTPUT_DIR}/neo4j_import/nodes.csv")
print(f"  6. {OUTPUT_DIR}/neo4j_import/relations.csv")
print(f"  7. {OUTPUT_DIR}/statistics_report.txt")
print("\n数据摘要:")
print(f"  概念: {len(concepts_df)}")
print(f"  实体: {len(entities_clean)}")
print(f"  关系: {len(relations_clean)}")
print("\n✓ 与main.py输出完全一致!")
